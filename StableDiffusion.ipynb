# %% [markdown]
# <a href="https://colab.research.google.com/github/DavidSaruni/Stable-Diffusion/blob/main/StableDiffusion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install diffusers

# %%
from diffusers import DiffusionPipeline

model_id = "stable-diffusion-v1-5/stable-diffusion-v1-5"
pipeline = DiffusionPipeline.from_pretrained(model_id, use_safetensors=True)
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]

# %%
prompt = "a photo of an astronaut riding a horse on mars"

# %%
pipeline = pipeline.to("cpu")

import torch

# If you need a generator, create it for CPU
generator = torch.Generator("cpu").manual_seed(0)

# Run the pipeline on the CPU
image = pipeline(prompt, generator=generator).images[0]

image
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>
